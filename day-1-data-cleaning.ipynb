# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# # 🧹 Data Cleaning Tutorial — Titanic Dataset
# *A Complete Step-by-Step Project for Beginners*

# %% [markdown]
# ## 📘 Project Overview
#
# Welcome aboard!
# In this tutorial, you’ll learn how to clean and prepare the **Titanic dataset** — one of the most popular and beginner-friendly datasets in data science.
#
# You’ll explore missing values, outliers, feature encoding, and more — ending with a fully cleaned dataset ready for modeling.

# %% [markdown]
# ### 🧭 Project Details
# - **Project Title:** Data Cleaning — Titanic Dataset
# - **Goal:** Learn to systematically inspect, clean, and prepare real-world data for machine learning.
# - **Final Deliverable:**
#   - A fully cleaned dataset: `titanic_cleaned.csv`
#   - Clear notes explaining each cleaning step

# %% [markdown]
# ### 📊 Dataset
# - **Name:** Titanic — Machine Learning from Disaster
# - **Link:** [https://www.kaggle.com/c/titanic/data](https://www.kaggle.com/c/titanic/data)
# - **Why It’s Ideal:**
#   - Realistic data imperfections
#   - Mix of numerical and categorical variables
#   - A classic dataset for developing foundational cleaning skills

# %% [markdown]
# ## 🪜 Step 1 — Load and Inspect the Data
#
# **Goal:** Understand the dataset structure and spot initial issues.
#
# **Tasks:**
# 1. Load the dataset (`train.csv`)
# 2. Inspect rows, columns, data types, and sample records
#
# **What to Look For:**
# - Columns with missing values (`Age`, `Cabin`, `Embarked`)
# - Data types (`object`, `int`, `float`)
# - Obvious anomalies (like unrealistic ages or missing cabins)
#
# **Deliverable:** A short written summary describing shape, column types, sample data, and initial observations.

# %% [markdown]
# ## 🧮 Step 2 — Handle Missing Values
#
# **Goal:** Decide how to handle missing data responsibly.
#
# **Typical Issues in Titanic:**
# - `Age`: Missing ~20%
# - `Cabin`: Missing ~77%
# - `Embarked`: Missing 2 rows
#
# **Strategy:**
# - Fill `Age` with **median** (skewed distribution).
# - Convert `Cabin` to a binary “has_cabin” flag.
# - Fill or drop `Embarked` as appropriate.
#
# **Why It Matters:**
# Proper handling of missing values avoids bias and improves model reliability.
#
# **Deliverable:** A written note of what method you used for each column and why.

# %% [markdown]
# ## ⚙️ Step 3 — Fix Data Types and Standardize Categories
#
# **Goal:** Ensure each column has the right data type and standardized categories.
#
# **Tasks:**
# 1. Convert identifiers like `PassengerId` to non-numeric if needed.
# 2. Make `Pclass`, `Sex`, and `Embarked` categorical.
# 3. Standardize text values (lowercase, strip spaces).
#
# **Why It Matters:**
# Accurate data types prevent errors in analysis and model training.
#
# **Deliverable:** A summary of columns adjusted and confirmation that categorical columns are consistent.

# %% [markdown]
# ## 🔍 Step 4 — Detect and Handle Outliers
#
# **Goal:** Identify unusual numeric values and decide whether to keep or remove them.
#
# **Methods to Use:**
# - **Statistical:** Z-Score or IQR method.
# - **Visual:** Boxplots or histograms.
# - **Logical:** Domain knowledge (e.g., large families or high fares are valid).
#
# **Why It Matters:**
# Outliers can distort summary statistics and model accuracy if not treated thoughtfully.
#
# **Deliverable:** A short explanation of which columns had outliers and your chosen handling method (keep, cap, or remove).

# %% [markdown]
# ## 🧩 Step 5 — Feature Engineering and Encoding
#
# **Goal:** Make data machine-readable and add meaningful new features.
#
# **Key Ideas:**
# - Encode categorical columns like `Sex` and `Embarked`.
# - Keep `Pclass` as an ordinal category.
# - Create new features such as:
#   - `Family_size = SibSp + Parch + 1`
#   - `has_cabin` from the earlier binary flag
#
# **Why It Matters:**
# Encoding and feature engineering improve model interpretability and predictive performance.
#
# **Deliverable:** A list of new features created and encoding strategies used.

# %% [markdown]
# ## 🧾 Step 6 — Final Dataset Review and Export
#
# **Goal:** Ensure the dataset is fully clean and ready for modeling.
#
# **Checklist:**
# 1. No missing values remain.
# 2. All columns have correct data types.
# 3. Numeric ranges are realistic.
# 4. Drop non-predictive columns like `PassengerId`.
# 5. Save the final dataset as `titanic_cleaned.csv`.
#
# **Why It Matters:**
# A thorough review guarantees data integrity before moving to the modeling phase.
#
# **Deliverable:** A short verification report confirming no nulls, correct data types, and export success.

# %% [markdown]
# ## 🎉 Project Complete — Data Cleaning: Titanic Dataset
#
# ### ✅ What You’ve Accomplished
# 1. Inspected and understood raw data
# 2. Handled missing values with sound logic
# 3. Fixed data types and standardized categories
# 4. Detected and reviewed outliers
# 5. Engineered and encoded powerful features
# 6. Verified and exported a modeling-ready dataset

# %% [markdown]
# ### 🧠 Skills Practiced
# - Systematic data cleaning workflow
# - Handling missing values intelligently
# - Feature engineering and encoding
# - Outlier detection and reasoning
# - Dataset validation and documentation

# %% [markdown]
# ### 💾 Deliverables
# - **Clean Dataset:** `titanic_cleaned.csv`
# - **Rows/Columns:** ~889 × 10
# - **Ready For:** Machine learning and feature analysis

# %% [markdown]
# ### 🚀 Next Project
# **Titanic Survival Prediction — Model Building & Evaluation**
#
# Use your cleaned dataset to build models like:
# - Logistic Regression
# - Decision Tree
# - Random Forest
# …and analyze which features most influence survival.

# %% [markdown]
# ### 🧩 Final Expert Tip
# > “A good data scientist cleans data as if they’ll have to explain every decision to a future version of themselves.”
# > Keep notes on every transformation — your future self will thank you.
